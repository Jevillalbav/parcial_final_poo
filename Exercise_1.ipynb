# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Drogueria:
  def __init__(self,nombre, medicamentos = []):
    self.nombre = nombre
    self.medicamentos = medicamentos

class Cliente:
  def __init__(self,cedula,nombre,telefono,direccion):
    self.cedula = cedula
    self.nombre = nombre
    self.telefono = telefono
    self.direccion = direccion

class Medico:
  def __init__(self,nombre,telefono,especialidad):
    self.nombre = nombre
    self.telefono = telefono
    self.especialidad = especialidad

class Medicamento:
  def __init__(self,sku,nombre_comercial,nombre_generico,precio_sin_impuesto,impuesto=0,peso_gramo=0,unidades=0):
    self.sku = sku
    self.nombre_comercial = nombre_comercial
    self.nombre_generico = nombre_generico
    self.precio_sin_impuesto = precio_sin_impuesto
    self.impuesto = impuesto
    self.peso_gramo = peso_gramo
    self.unidades = unidades

  def disminuir_existencia(self,sku,cantidad):
    pass


class MedicamentoLibre(Medicamento):
  def __init__(self,sku,nombre_comercial,nombre_generico,precio_sin_impuesto,contradicciones,impuesto=0,peso_gramo=0,unidades=0):
    super().__init__(sku,nombre_comercial,nombre_generico,precio_sin_impuesto,impuesto,peso_gramo,unidades)
    self.contradicciones = contradicciones

class MedicamentoRestringido(Medicamento):
  def __init__(self,sku,nombre_comercial,nombre_generico,precio_sin_impuesto,medico:Medico,dosis_maxima,impuesto=0,peso_gramo=0,unidades=0):
    super().__init__(sku,nombre_comercial,nombre_generico,precio_sin_impuesto,impuesto,peso_gramo,unidades)
    self.medico = medico
    self.dosis_maxima = dosis_maxima

class Factura:
  def __init__(self,cliente:Cliente,items=[]):
    self.cliente = cliente
    self.items = items

  def agregar_item(self,medicamento:Medicamento,cantidad):
    pass

  def quitar_item(self,medicamento:Medicamento):
    pass

  def facturar():
    pass

# %%
drogueria_eia = Drogueria('Drogueria EIA')
medicamento_1 = MedicamentoLibre('1705600230032','BAYCUTEN N','ACETATO DE DEXAMETASONA',20000,'Irritacion',0.19,20,10)
